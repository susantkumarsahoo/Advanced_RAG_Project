# %%
import os

ARTIFACTS_DIR = 'artifacts'
PDF_CHUNKS_PATH = 'chunk_data.pkl'
EMBADED_CHUNKS_PATH = 'embaded_chunks.pkl'


# Base directory: goes up three levels from config/settings.py
# settings.py -> config -> rag_project -> Advanced_RAG_Project (project root)
# BASE_DIR = os.path.dirname(os.path.dirname(os.path.dirname(os.path.abspath(__file__))))

# Automatically builds the full path to the PDF file
# pdf_data_path = os.path.join(BASE_DIR, "data_from_s3", "SupplyCode.pdf")

pdf_data_path = r'C:\Users\TPWODL\New folder_Content\Advanced_RAG_Project\data_from_s3\SupplyCode.pdf'



# rag_project/config/settings.py

# %%
import pickle
with open(r"C:\Users\TPWODL\New folder_Content\Advanced_RAG_Project\artifacts\chunk_data.pkl", "rb") as f:
    data = pickle.load(f)

print(type(data))        # should be list
print(len(data))         # should be number of chunks
print(type(data[0]))     # should be Document
print(data[0].page_content[:200])  # preview first chunk text
# Out:
# <class 'list'>
# 395
# <class 'langchain_core.documents.base.Document'>
# 1
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# ODISHA ELECTRICITY REGULATORY COMMISSION
# BHUBANESWAR – 751 021
# *****
#
# NOTIFICATION
# The 27 th August, 2019
#
# No.OERC/Engg/92/2003(Vol-VII)/1210 - In exercise of the

# %%
print(len(data))
# Out:
# 395

# %%
print((data[394]))     # should be Document
        # should be number of chunks
# Out:
# page_content='95
#
# 16. Malkangiri 42 Balimela(N) 11,796
# 17. Mayurbhanj 43 Karanjia(N) 22,865
#  44 Udala(N) 13,152
# 18. Nayagarh 45 Khandapada(N) 9,038
#  46 Daspala(N) 18470
#  47 Ranpur(N) 14715
#  48 Nayagarh(N) 17030
# 20. Nuapara 49 Khariar(N) 15,087
#  50 Khariar Road(N) 18,967
#  51 Nuapada(N) 16,208
# 25. Phulbani 52 G.Udayagiri(N) 11,302
#  53 Balliguda(N) 18,664
# 26. Puri 54 Konark(N) 16,779
#  55 Nimapara(N) 19,289
#  56 Pipili(N) 17,623
# 27. Rayagada 57 Gudari(N) 6,931
#  58 Gunupur(N) 24,162
# 28. Sambalpur 59 Kuchinda(N) 15,576
#  60 Redhakhol(N) 15,379
# 29. Subarnapur 61 Binika(N) 15,765
#  62 Sonepur(M) 20,770
# ...
